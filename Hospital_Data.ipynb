# %%
import pandas as pd
df = pd.read_csv('Hospitals.csv')
df.head()
# Out:
#             X          Y  OBJECTID        ID  \
# 0 -114.617494  34.833066      1001   7892363
# 1 -117.057065  32.776586      1002   1392120
# 2 -117.044162  32.774632      1003   1591942
# 3 -117.144645  32.756384      1004  23292104
# 4 -117.082337  32.685341      1005  34392050
#
#                                 NAME                  ADDRESS           CITY  \
# 0      COLORADO RIVER MEDICAL CENTER       1401 BAILEY AVENUE        NEEDLES
# 1   ALVARADO HOSPITAL MEDICAL CENTER       6655 ALVARADO ROAD      SAN DIEGO
# 2  ALVARADO PARKWAY INSTITUTE B.H.S.       7050 PARKWAY DRIVE        LA MESA
# 3       KINDRED HOSPITAL - SAN DIEGO  1940 EL CAJON BOULEVARD      SAN DIEGO
# 4           PARADISE VALLEY HOSPITAL  2400 EAST FOURTH STREET  NATIONAL CITY
#
#   STATE    ZIP           ZIP4  ...                  VAL_DATE  \
# 0    CA  92363  NOT AVAILABLE  ...  2014-02-10T00:00:00.000Z
# 1    CA  92120  NOT AVAILABLE  ...  2014-02-10T00:00:00.000Z
# ...

# %%
df_hosp= df.loc[(df.COUNTY=='NEW YORK')| (df.COUNTY== 'QUEENS'), :]

# %%
df_hosp.shape
# Out:
# (41, 34)

# %%
df_hosp.tail()
# Out:
#               X          Y  OBJECTID         ID  \
# 6013 -73.941624  40.803285       433  116810035
# 6027 -73.961590  40.804923       447  118710025
# 6028 -73.940687  40.841053       448  118810032
# 6029 -73.954332  40.764550       449  118910021
# 6396 -73.956596  40.764274       816  117510021
#
#                                                    NAME  \
# 6013                 HENRY J. CARTER SPECIALTY HOSPITAL
# 6027                             MOUNT SINAI ST. LUKE'S
# 6028  NEW YORK PRESBYTERIAN HOSPITAL - COLUMBIA PRES...
# 6029  NEW YORK PRESBYTERIAN HOSPITAL - NEW YORK WEIL...
# 6396   MEMORIAL HOSPITAL FOR CANCER AND ALLIED DISEASES
#
#                     ADDRESS      CITY STATE    ZIP           ZIP4  ...  \
# 6013       1752 PARK AVENUE  NEW YORK    NY  10035  NOT AVAILABLE  ...
# 6027  1111 AMSTERDAM AVENUE  NEW YORK    NY  10025  NOT AVAILABLE  ...
# 6028  622 WEST 168TH STREET  NEW YORK    NY  10032  NOT AVAILABLE  ...
# ...

# %%
df_hosp.sort_values(['X'], ascending=False)
#groups the hospitals by Longitude to better organize them by location
# Out:
#               X          Y  OBJECTID         ID  \
# 2365 -73.708106  40.754343      3366  114811040
# 2920 -73.725743  40.745537      3921  177611426
# 2919 -73.731525  40.741140      3920  171811427
# 5146 -73.753551  40.598708      7147   19811691
# 2402 -73.768676  40.690647      3403   11211425
# 2354 -73.804556  40.717072      3355   19511432
# 5997 -73.816115  40.700104       417   19711414
# 5145 -73.816466  40.755410      7146   19411355
# 6001 -73.825416  40.746772       421   20311355
# 2359 -73.851507  40.728995      3360   20011375
# 5996 -73.886080  40.744827       416   19611373
# 5155 -73.913050  40.873275      7156  115610034
# 2368 -73.924884  40.768295      3369  115511102
# 2913 -73.929127  40.790004      3914  170510035
# 2914 -73.930769  40.788305      3915  170610035
# 6012 -73.939861  40.814265       432  116710037
# 6028 -73.940687  40.841053       448  118810032
# 5994 -73.941283  40.839763       414   18610032
# ...
